# %%
import pandas as pd

# %%
df=pd.read_csv('logon.csv')

# %%
df.head()
# Out:
#                          id                 date     user       pc activity
# 0  {F3X8-Y2GT43DR-4906OHBL}  01/02/2010 02:19:18  DNS1758  PC-0414    Logon
# 1  {B4Q0-D0GM24KN-3704MAII}  01/02/2010 02:31:12  DNS1758  PC-0414   Logoff
# 2  {T7J1-D4HK34KV-5476TCIJ}  01/02/2010 02:34:02  DNS1758  PC-5313    Logon
# 3  {S4Y6-D8MQ05SA-0759HLIS}  01/02/2010 02:53:30  DNS1758  PC-5313   Logoff
# 4  {F3P0-E7FH78CV-4874FRGZ}  01/02/2010 04:07:31  DNS1758  PC-0012    Logon

# %%
df.shape
# Out:
# (3530285, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3530285 entries, 0 to 3530284
# Data columns (total 5 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   id        object
#  1   date      object
#  2   user      object
#  3   pc        object
#  4   activity  object
# dtypes: object(5)
# memory usage: 134.7+ MB

# %%
df.isna().sum()
# Out:
# id          0
# date        0
# user        0
# pc          0
# activity    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#changing the dtype of date column to DateTime
df['date']=pd.to_datetime(df['date'])

# %%
df.describe()
# Out:
#                                 date
# count                        3530285
# mean   2010-09-10 19:48:11.003055360
# min              2010-01-02 02:19:18
# 25%              2010-05-04 16:56:00
# 50%              2010-09-08 08:32:00
# 75%              2011-01-19 06:55:00
# max              2011-06-01 07:26:02

# %%
df.sample(10)
# Out:
#                                id                date     user       pc  \
# 2158576  {J6V6-K4CH62GP-4493BQSR} 2010-11-03 07:29:00  VKM2376  PC-0717
# 2358204  {B9N1-C5TJ50ZC-7482MXAV} 2010-12-03 08:07:00  KWC3812  PC-8397
# 1140596  {L2M8-B2RG05NL-8526HSGP} 2010-06-10 07:30:00  EBS2201  PC-4723
# 269356   {L7J2-H4BL82SA-4510MUIF} 2010-02-08 20:20:45  JPS2432  PC-1945
# 1515444  {J9D4-O3RN12FQ-2211TVTU} 2010-08-03 08:23:00  NMW0896  PC-8493
# 3301034  {M3C7-T5JQ18DQ-6622FSVT} 2011-04-26 16:29:00  AAC3270  PC-5225
# 1574081  {A1S0-P3WB44GJ-8017YOLB} 2010-08-11 08:02:00  LSM2234  PC-0685
# 290477   {D3N8-N4HO15XK-0514HBME} 2010-02-11 07:30:00  CKH0705  PC-1418
# 898263   {V3X8-B7HI44GD-3458VTRZ} 2010-05-06 08:19:00  TRV2966  PC-4776
# 2413856  {S4I2-Y7MT11YU-1219TGOW} 2010-12-11 18:31:00  ZAR0404  PC-7841
#
#         activity
# 2158576    Logon
# 2358204    Logon
# 1140596    Logon
# 269356     Logon
# 1515444    Logon
# 3301034   Logoff
# 1574081    Logon
# 290477     Logon
# 898263     Logon
# 2413856   Logoff

# %%
df['user'].nunique(),df['pc'].nunique()
# Out:
# (4000, 4400)

# %%
df['user'].unique()
# Out:
# array(['DNS1758', 'ANC1950', 'SAB1954', ..., 'HVR0633', 'CJS1986',
#        'WKG0150'], dtype=object)

# %%
df[(df['user']=='DNS1758') & (df['activity']=='Logon')].describe()
# Out:
#                                 date
# count                           2217
# mean   2010-09-15 18:08:44.268380672
# min              2010-01-02 02:19:18
# 25%              2010-05-10 23:05:23
# 50%              2010-09-15 23:42:24
# 75%              2011-01-22 14:51:58
# max              2011-05-31 20:50:55

# %%
df[(df['user']=='DNS1758') & (df['activity']=='Logoff')].describe()
# Out:
#                                 date
# count                           1887
# mean   2010-09-15 11:02:38.063592960
# min              2010-01-02 02:31:12
# 25%              2010-05-11 08:09:09
# 50%              2010-09-15 22:10:57
# 75%              2011-01-22 15:25:00
# max              2011-05-31 21:08:15

# %%
df['window'] = df['date'].dt.floor('h')

# %%
df.head()
# Out:
#                          id                date     user       pc activity  \
# 0  {F3X8-Y2GT43DR-4906OHBL} 2010-01-02 02:19:18  DNS1758  PC-0414    Logon
# 1  {B4Q0-D0GM24KN-3704MAII} 2010-01-02 02:31:12  DNS1758  PC-0414   Logoff
# 2  {T7J1-D4HK34KV-5476TCIJ} 2010-01-02 02:34:02  DNS1758  PC-5313    Logon
# 3  {S4Y6-D8MQ05SA-0759HLIS} 2010-01-02 02:53:30  DNS1758  PC-5313   Logoff
# 4  {F3P0-E7FH78CV-4874FRGZ} 2010-01-02 04:07:31  DNS1758  PC-0012    Logon
#
#                window
# 0 2010-01-02 02:00:00
# 1 2010-01-02 02:00:00
# 2 2010-01-02 02:00:00
# 3 2010-01-02 02:00:00
# 4 2010-01-02 04:00:00

# %%
grouped=df.groupby(['window','user'])

# %%
df['is_logon']  = (df['activity'] == 'Logon').astype(int)
df['is_logoff'] = (df['activity'] == 'Logoff').astype(int)

# %%
features = df.groupby(['user','window']).agg(
    logon_count = ('is_logon','sum'),
    logoff_count = ('is_logoff','sum'),
    unique_pcs = ('pc','nunique')
).reset_index()

# %%
features
# Out:
#             user              window  logon_count  logoff_count  unique_pcs
# 0        AAB0162 2010-01-04 07:00:00            1             0           1
# 1        AAB0162 2010-01-04 18:00:00            0             1           1
# 2        AAB0162 2010-01-05 07:00:00            1             0           1
# 3        AAB0162 2010-01-05 18:00:00            0             1           1
# 4        AAB0162 2010-01-06 07:00:00            1             0           1
# ...          ...                 ...          ...           ...         ...
# 3366259  ZZO2997 2011-05-26 14:00:00            0             1           1
# 3366260  ZZO2997 2011-05-27 07:00:00            1             0           1
# 3366261  ZZO2997 2011-05-27 14:00:00            0             1           1
# 3366262  ZZO2997 2011-05-31 07:00:00            1             0           1
# 3366263  ZZO2997 2011-05-31 14:00:00            0             1           1
#
# [3366264 rows x 5 columns]

# %%
features[(features['logon_count']==0)&(features['logoff_count']==1)] #checking the count of half sessions
# Out:
#             user              window  logon_count  logoff_count  unique_pcs
# 1        AAB0162 2010-01-04 18:00:00            0             1           1
# 3        AAB0162 2010-01-05 18:00:00            0             1           1
# 5        AAB0162 2010-01-06 18:00:00            0             1           1
# 7        AAB0162 2010-01-07 18:00:00            0             1           1
# 9        AAB0162 2010-01-08 18:00:00            0             1           1
# ...          ...                 ...          ...           ...         ...
# 3366255  ZZO2997 2011-05-24 14:00:00            0             1           1
# 3366257  ZZO2997 2011-05-25 14:00:00            0             1           1
# 3366259  ZZO2997 2011-05-26 14:00:00            0             1           1
# 3366261  ZZO2997 2011-05-27 14:00:00            0             1           1
# 3366263  ZZO2997 2011-05-31 14:00:00            0             1           1
#
# [1439501 rows x 5 columns]

# %%
features[(features['logon_count']==1)&(features['logoff_count']==0)] #checking the count of half sessions
# Out:
#             user              window  logon_count  logoff_count  unique_pcs
# 0        AAB0162 2010-01-04 07:00:00            1             0           1
# 2        AAB0162 2010-01-05 07:00:00            1             0           1
# 4        AAB0162 2010-01-06 07:00:00            1             0           1
# 6        AAB0162 2010-01-07 07:00:00            1             0           1
# 8        AAB0162 2010-01-08 07:00:00            1             0           1
# ...          ...                 ...          ...           ...         ...
# 3366254  ZZO2997 2011-05-24 07:00:00            1             0           1
# 3366256  ZZO2997 2011-05-25 07:00:00            1             0           1
# 3366258  ZZO2997 2011-05-26 07:00:00            1             0           1
# 3366260  ZZO2997 2011-05-27 07:00:00            1             0           1
# 3366262  ZZO2997 2011-05-31 07:00:00            1             0           1
#
# [1803463 rows x 5 columns]

# %%
features['logon_count'].unique(),features['logoff_count'].unique()
# Out:
# (array([1, 0, 2, 3, 4, 5]), array([0, 1, 2, 3, 4, 5]))

# %%
user_stats = features.groupby('user').agg(
    avg_logon = ('logon_count','mean'),
    std_logon = ('logon_count','std'),
    avg_pcs   = ('unique_pcs','mean'),
    std_pcs=('unique_pcs','std')
)
user_stats
# Out:
#          avg_logon  std_logon  avg_pcs  std_pcs
# user
# AAB0162   0.499297   0.500351      1.0      0.0
# AAB0398   0.500000   0.500351      1.0      0.0
# AAC0610   0.633333   0.482124      1.0      0.0
# AAC0668   0.500000   0.500351      1.0      0.0
# AAC3270   0.500000   0.500351      1.0      0.0
# ...            ...        ...      ...      ...
# ZVB2656   0.500000   0.500351      1.0      0.0
# ZVS1637   0.500000   0.500351      1.0      0.0
# ZWS3625   0.500000   0.500351      1.0      0.0
# ZXM3086   0.500000   0.500351      1.0      0.0
# ZZO2997   0.500000   0.500351      1.0      0.0
#
# [4000 rows x 4 columns]

# %%
user_stats.describe()
# Out:
#          avg_logon    std_logon      avg_pcs      std_pcs
# count  4000.000000  4000.000000  4000.000000  4000.000000
# mean      0.558038     0.499832     1.007113     0.038529
# std       0.081835     0.019571     0.023546     0.080672
# min       0.498592     0.476786     1.000000     0.000000
# 25%       0.500000     0.494049     1.000000     0.000000
# 50%       0.500000     0.500351     1.000000     0.000000
# 75%       0.640404     0.500351     1.003428     0.058482
# max       0.896739     0.664649     1.176401     0.487452

# %%
user_stats['avg_pcs'].max()
# Out:
# 1.176401179941003

# %%
features.head()
# Out:
#       user              window  logon_count  logoff_count  unique_pcs
# 0  AAB0162 2010-01-04 07:00:00            1             0           1
# 1  AAB0162 2010-01-04 18:00:00            0             1           1
# 2  AAB0162 2010-01-05 07:00:00            1             0           1
# 3  AAB0162 2010-01-05 18:00:00            0             1           1
# 4  AAB0162 2010-01-06 07:00:00            1             0           1

# %%
features['hour']=features['window'].dt.hour

# %%
features.groupby('hour')['logon_count'].mean()
#checking the mean at each hour in the day by all users
# Out:
# hour
# 0     1.198852
# 1     0.855245
# 2     0.806606
# 3     0.775210
# 4     0.735733
# 5     0.710431
# 6     0.952959
# 7     1.003372
# 8     1.002671
# 9     0.962839
# 10    0.919234
# 11    0.963688
# 12    0.981879
# 13    0.976760
# 14    0.531610
# 15    0.055518
# 16    0.018347
# 17    0.018473
# 18    0.022106
# 19    0.076057
# 20    0.305474
# 21    0.949044
# 22    0.979495
# 23    1.075243
# Name: logon_count, dtype: float64

# %%
enriched_df=pd.merge(features,user_stats,on='user')
enriched_df
# Out:
#             user              window  logon_count  logoff_count  unique_pcs  \
# 0        AAB0162 2010-01-04 07:00:00            1             0           1
# 1        AAB0162 2010-01-04 18:00:00            0             1           1
# 2        AAB0162 2010-01-05 07:00:00            1             0           1
# 3        AAB0162 2010-01-05 18:00:00            0             1           1
# 4        AAB0162 2010-01-06 07:00:00            1             0           1
# ...          ...                 ...          ...           ...         ...
# 3366259  ZZO2997 2011-05-26 14:00:00            0             1           1
# 3366260  ZZO2997 2011-05-27 07:00:00            1             0           1
# 3366261  ZZO2997 2011-05-27 14:00:00            0             1           1
# 3366262  ZZO2997 2011-05-31 07:00:00            1             0           1
# 3366263  ZZO2997 2011-05-31 14:00:00            0             1           1
#
#          hour  avg_logon  std_logon  avg_pcs  std_pcs
# 0           7   0.499297   0.500351      1.0      0.0
# 1          18   0.499297   0.500351      1.0      0.0
# 2           7   0.499297   0.500351      1.0      0.0
# 3          18   0.499297   0.500351      1.0      0.0
# 4           7   0.499297   0.500351      1.0      0.0
# ...       ...        ...        ...      ...      ...
# 3366259    14   0.500000   0.500351      1.0      0.0
# 3366260     7   0.500000   0.500351      1.0      0.0
# 3366261    14   0.500000   0.500351      1.0      0.0
# 3366262     7   0.500000   0.500351      1.0      0.0
# 3366263    14   0.500000   0.500351      1.0      0.0
#
# [3366264 rows x 10 columns]

# %%
enriched_df['z_logon']=(enriched_df['logon_count']-enriched_df['avg_logon'])/enriched_df['std_logon']
enriched_df['z_pcs']=(enriched_df['unique_pcs']-enriched_df['avg_pcs'])/(enriched_df['std_pcs']+0.01)

# %%
enriched_df.head()
# Out:
#       user              window  logon_count  logoff_count  unique_pcs  hour  \
# 0  AAB0162 2010-01-04 07:00:00            1             0           1     7
# 1  AAB0162 2010-01-04 18:00:00            0             1           1    18
# 2  AAB0162 2010-01-05 07:00:00            1             0           1     7
# 3  AAB0162 2010-01-05 18:00:00            0             1           1    18
# 4  AAB0162 2010-01-06 07:00:00            1             0           1     7
#
#    avg_logon  std_logon  avg_pcs  std_pcs   z_logon  z_pcs
# 0   0.499297   0.500351      1.0      0.0  1.000703    0.0
# 1   0.499297   0.500351      1.0      0.0 -0.997892    0.0
# 2   0.499297   0.500351      1.0      0.0  1.000703    0.0
# 3   0.499297   0.500351      1.0      0.0 -0.997892    0.0
# 4   0.499297   0.500351      1.0      0.0  1.000703    0.0

# %%
enriched_df['night_flag']=(enriched_df['hour']<6)|(enriched_df['hour']>22)

# %%
enriched_df[enriched_df['night_flag']==True]
# Out:
#             user              window  logon_count  logoff_count  unique_pcs  \
# 1491     AAC0610 2010-02-06 00:00:00            1             0           1
# 1492     AAC0610 2010-02-06 04:00:00            0             1           1
# 1526     AAC0610 2010-02-24 05:00:00            0             1           1
# 1552     AAC0610 2010-03-09 00:00:00            1             0           1
# 1553     AAC0610 2010-03-09 04:00:00            0             1           1
# ...          ...                 ...          ...           ...         ...
# 3360949  ZRM0694 2011-04-12 05:00:00            0             1           1
# 3361012  ZRM0694 2011-05-01 23:00:00            1             0           1
# 3361013  ZRM0694 2011-05-02 05:00:00            0             1           1
# 3361051  ZRM0694 2011-05-14 00:00:00            1             0           1
# 3361052  ZRM0694 2011-05-14 05:00:00            0             1           1
#
#          hour  avg_logon  std_logon   avg_pcs   std_pcs   z_logon     z_pcs  \
# 1491        0   0.633333   0.482124  1.000000  0.000000  0.760523  0.000000
# 1492        4   0.633333   0.482124  1.000000  0.000000 -1.313631  0.000000
# 1526        5   0.633333   0.482124  1.000000  0.000000 -1.313631  0.000000
# 1552        0   0.633333   0.482124  1.000000  0.000000  0.760523  0.000000
# 1553        4   0.633333   0.482124  1.000000  0.000000 -1.313631  0.000000
# ...       ...        ...        ...       ...       ...       ...       ...
# 3360949     5   0.644048   0.504677  1.019551  0.138493 -1.276160 -0.131666
# 3361012    23   0.644048   0.504677  1.019551  0.138493  0.705307 -0.131666
# 3361013     5   0.644048   0.504677  1.019551  0.138493 -1.276160 -0.131666
# 3361051     0   0.644048   0.504677  1.019551  0.138493  0.705307 -0.131666
# 3361052     5   0.644048   0.504677  1.019551  0.138493 -1.276160 -0.131666
#
#          night_flag
# 1491           True
# 1492           True
# 1526           True
# 1552           True
# 1553           True
# ...             ...
# 3360949        True
# 3361012        True
# 3361013        True
# 3361051        True
# 3361052        True
#
# [62023 rows x 13 columns]

# %%
enriched_df['behavior_score']= 0.4* abs(enriched_df['z_logon']) + 0.35*abs(enriched_df['z_pcs']) + 0.25*enriched_df['night_flag']

# %%
0.4* abs(enriched_df['z_logon']) + 0.35*abs(enriched_df['z_pcs']) + 0.25*enriched_df['night_flag']
# Out:
# 0          0.400281
# 1          0.399157
# 2          0.400281
# 3          0.399157
# 4          0.400281
#              ...
# 3366259    0.399719
# 3366260    0.399719
# 3366261    0.399719
# 3366262    0.399719
# 3366263    0.399719
# Length: 3366264, dtype: float64

# %%
enriched_df['behavior_score'].describe() #checking the scores
# Out:
# count    3.366264e+06
# mean     4.221807e-01
# std      2.479288e-01
# min      1.910926e-01
# 25%      3.240445e-01
# 50%      3.997190e-01
# 75%      4.002812e-01
# max      9.901351e+00
# Name: behavior_score, dtype: float64

# %%
enriched_df.sort_values('behavior_score', ascending=False).head(10)
# Out:
#             user              window  logon_count  logoff_count  unique_pcs  \
# 807965   DBG0477 2010-03-01 14:00:00            2             1           2
# 200808   ANF3332 2010-05-10 10:00:00            2             1           2
# 1183678  GER1997 2010-03-19 13:00:00            2             0           2
# 323564   BBW0594 2010-06-01 08:00:00            2             1           2
# 2168343  MGM0569 2011-03-29 08:00:00            2             1           2
# 2077390  LWB2851 2011-05-17 16:00:00            0             2           2
# 3086115  TZM0851 2011-02-03 09:00:00            2             1           2
# 2177353  MHS2634 2011-02-25 11:00:00            2             1           2
# 229616   ARC3034 2011-03-09 13:00:00            2             0           2
# 750718   CTB3481 2010-03-04 09:00:00            2             0           2
#
#          hour  avg_logon  std_logon   avg_pcs   std_pcs   z_logon      z_pcs  \
# 807965     14   0.630687   0.484680  1.000892  0.029867  2.825191  25.060785
# 200808     10   0.634146   0.483759  1.000903  0.030056  2.823417  24.942712
# 1183678    13   0.635786   0.483312  1.000908  0.030137  2.822634  24.891766
# 323564      8   0.634742   0.483676  1.000939  0.030643  2.822672  24.581640
# 2168343     8   0.644403   0.480881  1.000941  0.030671  2.818985  24.564182
# 2077390    16   0.641886   0.479637  1.000799  0.028273 -1.338274  26.107218
# 3086115     9   0.644509   0.480902  1.000963  0.031039  2.818643  24.343862
# 2177353    11   0.644814   0.480845  1.000978  0.031281  2.818342  24.200773
# 229616     13   0.642717   0.481486  1.000984  0.031373  2.818947  24.146685
# 750718      9   0.642012   0.481699  1.000986  0.031404  2.819164  24.128603
#
#          night_flag  behavior_score
# 807965        False        9.901351
# 200808        False        9.859316
# 1183678       False        9.841172
# 323564        False        9.732643
# 2168343       False        9.725058
# 2077390       False        9.672836
# 3086115       False        9.647809
# 2177353       False        9.597607
# 229616        False        9.578919
# 750718        False        9.572677

# %%
enriched_df.head()
# Out:
#       user              window  logon_count  logoff_count  unique_pcs  hour  \
# 0  AAB0162 2010-01-04 07:00:00            1             0           1     7
# 1  AAB0162 2010-01-04 18:00:00            0             1           1    18
# 2  AAB0162 2010-01-05 07:00:00            1             0           1     7
# 3  AAB0162 2010-01-05 18:00:00            0             1           1    18
# 4  AAB0162 2010-01-06 07:00:00            1             0           1     7
#
#    avg_logon  std_logon  avg_pcs  std_pcs   z_logon  z_pcs  night_flag  \
# 0   0.499297   0.500351      1.0      0.0  1.000703    0.0       False
# 1   0.499297   0.500351      1.0      0.0 -0.997892    0.0       False
# 2   0.499297   0.500351      1.0      0.0  1.000703    0.0       False
# 3   0.499297   0.500351      1.0      0.0 -0.997892    0.0       False
# 4   0.499297   0.500351      1.0      0.0  1.000703    0.0       False
#
#    behavior_score
# 0        0.400281
# 1        0.399157
# 2        0.400281
# 3        0.399157
# 4        0.400281

# %%
enriched_df.to_csv('enriched_logon.csv',index=False)
